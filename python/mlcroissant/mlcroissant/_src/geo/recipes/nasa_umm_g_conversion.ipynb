# %%
# !cd /home/hks/croissant/python/mlcroissant && pip install -e .[geo]
# Out:
# Obtaining file:///home/hks/croissant/python/mlcroissant
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 19.7 MB/s eta 0:00:00a 0:00:01
# ...
#   Building editable for mlcroissant (pyproject.toml) ... done
#   Created wheel for mlcroissant: filename=mlcroissant-1.0.21-0.editable-py2.py3-none-any.whl size=7307 sha256=c37c66e56dcb08c50dec9bdde2d2292377e7dd50fb005e7016615875e33ecf6b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g4_1wixe/wheels/0b/e1/66/9abfbdfe0af0732a93c6883ce657ddfb5a6b4421a3d390ee78
# Successfully built mlcroissant
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.7.0
#     Uninstalling fsspec-2025.7.0:
#       Successfully uninstalled fsspec-2025.7.0
#   Attempting uninstall: botocore
# ...

# %%
import mlcroissant
from mlcroissant._src.geo import umm_g_to_geocroissant

# %%
umm_g_path = "../umm.json"  # Go up from recipes/ to geo/
output_path = "geo_umm.json"
umm_g_to_geocroissant(umm_g_path, output_path)
# Out:
# {'@context': {'@language': 'en',
#   '@vocab': 'https://schema.org/',
#   'cr': 'http://mlcommons.org/croissant/',
#   'geocr': 'http://mlcommons.org/geocroissant/',
#   'dct': 'http://purl.org/dc/terms/',
#   'sc': 'https://schema.org/',
#   'citeAs': 'cr:citeAs',
#   'column': 'cr:column',
#   'conformsTo': 'dct:conformsTo',
#   'data': {'@id': 'cr:data', '@type': '@json'},
#   'dataBiases': 'cr:dataBiases',
#   'dataCollection': 'cr:dataCollection',
#   'dataType': {'@id': 'cr:dataType', '@type': '@vocab'},
#   'extract': 'cr:extract',
#   'field': 'cr:field',
#   'fileProperty': 'cr:fileProperty',
#   'fileObject': 'cr:fileObject',
#   'fileSet': 'cr:fileSet',
#   'format': 'cr:format',
#   'includes': 'cr:includes',
#   'isLiveDataset': 'cr:isLiveDataset',
#   'jsonPath': 'cr:jsonPath',
#   'key': 'cr:key',
#   'md5': {'@id': 'cr:md5', '@type': 'sc:Text'},
#   'sha256': {'@id': 'cr:sha256', '@type': 'sc:Text'},
#   'parentField': 'cr:parentField',
#   'path': 'cr:path',
# ...

# %%
# !mlcroissant validate --jsonld=geo_umm.json
# Out:
# W0820 14:38:52.924830 140567495722816 rdf.py:81] WARNING: The JSON-LD `@context` is not standard. Refer to the official @context (e.g., from the example datasets in https://github.com/mlcommons/croissant/tree/main/datasets/1.0). The different keys are: {'rai', 'examples', 'samplingRate'}
# I0820 14:38:52.975115 140567495722816 validate.py:53] Done.

# %%
#URL

# %%
umm_g_url = "https://cmr.earthdata.nasa.gov/search/granules.umm_json?concept_id=G2700719831-LPCLOUD" 
output_path_url = "geo_umm_url.json"
umm_g_to_geocroissant(umm_g_url, output_path_url)
# Out:
# {'@context': {'@language': 'en',
#   '@vocab': 'https://schema.org/',
#   'cr': 'http://mlcommons.org/croissant/',
#   'geocr': 'http://mlcommons.org/geocroissant/',
#   'dct': 'http://purl.org/dc/terms/',
#   'sc': 'https://schema.org/',
#   'citeAs': 'cr:citeAs',
#   'column': 'cr:column',
#   'conformsTo': 'dct:conformsTo',
#   'data': {'@id': 'cr:data', '@type': '@json'},
#   'dataBiases': 'cr:dataBiases',
#   'dataCollection': 'cr:dataCollection',
#   'dataType': {'@id': 'cr:dataType', '@type': '@vocab'},
#   'extract': 'cr:extract',
#   'field': 'cr:field',
#   'fileProperty': 'cr:fileProperty',
#   'fileObject': 'cr:fileObject',
#   'fileSet': 'cr:fileSet',
#   'format': 'cr:format',
#   'includes': 'cr:includes',
#   'isLiveDataset': 'cr:isLiveDataset',
#   'jsonPath': 'cr:jsonPath',
#   'key': 'cr:key',
#   'md5': {'@id': 'cr:md5', '@type': 'sc:Text'},
#   'sha256': {'@id': 'cr:sha256', '@type': 'sc:Text'},
#   'parentField': 'cr:parentField',
#   'path': 'cr:path',
# ...

# %%
# !mlcroissant validate --jsonld=geo_umm_url.json
# Out:
# W0820 14:38:56.274489 139998136624960 rdf.py:81] WARNING: The JSON-LD `@context` is not standard. Refer to the official @context (e.g., from the example datasets in https://github.com/mlcommons/croissant/tree/main/datasets/1.0). The different keys are: {'examples', 'rai', 'samplingRate'}
# I0820 14:38:56.330254 139998136624960 validate.py:53] Done.
